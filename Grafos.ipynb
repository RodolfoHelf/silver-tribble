# %%
import sys
# !{sys.executable} -m pip install py2neo
# Out:
# ...
#     100% |████████████████████████████████| 71kB 2.4MB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 194kB 6.8MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 256kB 12.3MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 133kB 21.9MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for py2neo ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/49/b4/f8/df22db284f7ec2f6c26f87a87ff38c6c8ffa84baf2930ef0fe
#   Running setup.py bdist_wheel for neo4j-driver ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/d2/50/18/d27b3f60fa06c256abde78f2ef36fca66e7eb115d8a3745636
#   Running setup.py bdist_wheel for neotime ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/19/1c/63/e1777cae4998cb32c5ae5bb1901def45cc94de3abff4d7053d
# Successfully built py2neo neo4j-driver neotime
# jupyter-console 6.0.0 has requirement prompt_toolkit<2.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.15 which is incompatible.
# ...

# %%
from py2neo import Graph, Path
graph = Graph("https://localhost:7473",auth=("neo4j", "123"))


graph.delete_all()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3_501/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/anaconda3_501/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~/anaconda3_501/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
